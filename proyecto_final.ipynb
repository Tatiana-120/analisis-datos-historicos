# %% [markdown]
# # Asignación Final: Análisis de Datos Históricos
# ### Proyecto completado por Tatiana

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Extracción de Datos de Ingresos de GameStop

# %%
html_data_2 = """<table><thead><tr><th>GameStop Quarterly Revenue</th></tr></thead><tbody><tr><td>2020-04-30</td><td>$542</td></tr><tr><td>2020-01-31</td><td>$2,194</td></tr><tr><td>2019-10-31</td><td>$1,439</td></tr><tr><td>2019-07-31</td><td>$1,286</td></tr><tr><td>2019-04-30</td><td>$1,548</td></tr><tr><td>2019-01-31</td><td>$3,063</td></tr></tbody></table>"""
soup = BeautifulSoup(html_data_2, 'html.parser')
gme_revenue = pd.read_html(str(soup))[0]
gme_revenue.columns = ['Date', 'Revenue']
gme_revenue["Revenue"] = gme_revenue['Revenue'].str.replace(r'[\$,]', '', regex=True)
gme_revenue.tail()
